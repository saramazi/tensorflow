# %%
# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

import tensorflow as tf

# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# Create model
def conv2d(img, w, b):
    return tf.nn.relu(tf.nn.bias_add(tf.nn.conv2d(img, w, strides=[1, 1, 1, 1], padding='VALID'), b))

def max_pool(img, k):
    return tf.nn.max_pool(img, ksize=[1, k, k, 1], strides=[1, k, k, 1], padding='VALID')

# Store layers weight & bias

wc1 = tf.Variable(tf.random_normal([5, 5, 1, 32])) # 5x5 conv, 1 input, 32 outputs
wc2 = tf.Variable(tf.random_normal([5, 5, 32, 64])) # 5x5 conv, 32 inputs, 64 outputs
wd1 = tf.Variable(tf.random_normal([4 * 4 * 64, 1024])) # fully connected, 7*7*64 inputs, 1024 outputs
wout = tf.Variable(tf.random_normal([1024, n_classes])) # 1024 inputs, 10 outputs (class prediction)


bc1 = tf.Variable(tf.random_normal([32]))
bc2 = tf.Variable(tf.random_normal([64]))
bd1 = tf.Variable(tf.random_normal([1024]))
bout = tf.Variable(tf.random_normal([n_classes]))


# Construct model
_X = tf.reshape(x, shape=[-1, 28, 28, 1])


# Convolution Layer
conv1 = conv2d(_X,wc1,bc1)

# Max Pooling (down-sampling)
conv1 = max_pool(conv1, k=2)

# Apply Dropout
conv1 = tf.nn.dropout(conv1,keep_prob)


# Convolution Layer
conv2 = conv2d(conv1,wc2,bc2)

# Max Pooling (down-sampling)
conv2 = max_pool(conv2, k=2)

# Apply Dropout
conv2 = tf.nn.dropout(conv2, keep_prob)


# Fully connected layer
dense1 = tf.reshape(conv2, [-1, wd1.get_shape().as_list()[0]]) # Reshape conv2 output to fit dense layer input
dense1 = tf.nn.relu(tf.add(tf.matmul(dense1, wd1),bd1)) # Relu activation
dense1 = tf.nn.dropout(dense1, keep_prob) # Apply Dropout

# Output, class prediction
pred = tf.add(tf.matmul(dense1, wout), bout)

#pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits = pred, labels = y))
optimizer = tf.train.AdamOptimizer(learning_rate = learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        # Fit training using batch data
        sess.run(optimizer, { x: batch_xs, y: batch_ys, keep_prob: dropout })
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, { x: batch_xs, y: batch_ys, keep_prob: 1. })
            # Calculate batch loss
            loss = sess.run(cost, { x: batch_xs, y: batch_ys, keep_prob: 1. })
            print("Iter " + str(step * batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", sess.run(accuracy, {x: mnist.test.images[:256], y: mnist.test.labels[:256], keep_prob: 1.}))
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From <ipython-input-4-92f4b8f68a1d>:87: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Iter 1280, Minibatch Loss= 18006.869141, Training Accuracy= 0.15625
# Iter 2560, Minibatch Loss= 11199.600586, Training Accuracy= 0.32031
# Iter 3840, Minibatch Loss= 9137.326172, Training Accuracy= 0.42969
# Iter 5120, Minibatch Loss= 7154.670410, Training Accuracy= 0.45312
# Iter 6400, Minibatch Loss= 5184.586426, Training Accuracy= 0.52344
# Iter 7680, Minibatch Loss= 3735.480469, Training Accuracy= 0.60938
# Iter 8960, Minibatch Loss= 4856.188477, Training Accuracy= 0.59375
# Iter 10240, Minibatch Loss= 3462.835449, Training Accuracy= 0.64062
# Iter 11520, Minibatch Loss= 3615.516113, Training Accuracy= 0.64062
# Iter 12800, Minibatch Loss= 2225.031738, Training Accuracy= 0.75781
# Iter 14080, Minibatch Loss= 1807.171631, Training Accuracy= 0.78125
# Iter 15360, Minibatch Loss= 1697.013916, Training Accuracy= 0.75781
# Iter 16640, Minibatch Loss= 1725.659668, Training Accuracy= 0.76562
# Iter 17920, Minibatch Loss= 1605.063965, Training Accuracy= 0.81250
# Iter 19200, Minibatch Loss= 2169.881836, Training Accuracy= 0.79688
# Iter 20480, Minibatch Loss= 2288.644531, Training Accuracy= 0.78125
# Iter 21760, Minibatch Loss= 1066.255859, Training Accuracy= 0.84375
# Iter 23040, Minibatch Loss= 1191.564331, Training Accuracy= 0.78125
# Iter 24320, Minibatch Loss= 791.968750, Training Accuracy= 0.85156
# Iter 25600, Minibatch Loss= 1326.168823, Training Accuracy= 0.75781
# Iter 26880, Minibatch Loss= 794.082153, Training Accuracy= 0.82812
# Iter 28160, Minibatch Loss= 1883.926270, Training Accuracy= 0.80469
# Iter 29440, Minibatch Loss= 863.256592, Training Accuracy= 0.89062
# Iter 30720, Minibatch Loss= 720.754456, Training Accuracy= 0.85938
# Iter 32000, Minibatch Loss= 1041.422363, Training Accuracy= 0.81250
# Iter 33280, Minibatch Loss= 966.249390, Training Accuracy= 0.82031
# Iter 34560, Minibatch Loss= 747.940918, Training Accuracy= 0.85938
# Iter 35840, Minibatch Loss= 908.026917, Training Accuracy= 0.82812
# Iter 37120, Minibatch Loss= 856.994568, Training Accuracy= 0.81250
# Iter 38400, Minibatch Loss= 903.535217, Training Accuracy= 0.80469
# Iter 39680, Minibatch Loss= 813.083618, Training Accuracy= 0.89844
# Iter 40960, Minibatch Loss= 237.090363, Training Accuracy= 0.93750
# Iter 42240, Minibatch Loss= 852.686157, Training Accuracy= 0.84375
# Iter 43520, Minibatch Loss= 576.594116, Training Accuracy= 0.86719
# Iter 44800, Minibatch Loss= 406.535095, Training Accuracy= 0.85938
# Iter 46080, Minibatch Loss= 551.979248, Training Accuracy= 0.86719
# Iter 47360, Minibatch Loss= 508.565063, Training Accuracy= 0.88281
# Iter 48640, Minibatch Loss= 263.532593, Training Accuracy= 0.92969
# Iter 49920, Minibatch Loss= 993.522095, Training Accuracy= 0.83594
# Iter 51200, Minibatch Loss= 367.025391, Training Accuracy= 0.90625
# Iter 52480, Minibatch Loss= 563.960876, Training Accuracy= 0.85938
# Iter 53760, Minibatch Loss= 348.563446, Training Accuracy= 0.91406
# Iter 55040, Minibatch Loss= 221.256943, Training Accuracy= 0.88281
# Iter 56320, Minibatch Loss= 340.922180, Training Accuracy= 0.91406
# Iter 57600, Minibatch Loss= 617.159729, Training Accuracy= 0.86719
# Iter 58880, Minibatch Loss= 603.137268, Training Accuracy= 0.85156
# Iter 60160, Minibatch Loss= 326.301147, Training Accuracy= 0.93750
# Iter 61440, Minibatch Loss= 383.999451, Training Accuracy= 0.88281
# Iter 62720, Minibatch Loss= 405.114014, Training Accuracy= 0.87500
# Iter 64000, Minibatch Loss= 418.734741, Training Accuracy= 0.86719
# Iter 65280, Minibatch Loss= 261.113159, Training Accuracy= 0.92188
# Iter 66560, Minibatch Loss= 442.603302, Training Accuracy= 0.86719
# Iter 67840, Minibatch Loss= 824.575439, Training Accuracy= 0.82031
# Iter 69120, Minibatch Loss= 703.377502, Training Accuracy= 0.85156
# Iter 70400, Minibatch Loss= 362.959106, Training Accuracy= 0.89062
# Iter 71680, Minibatch Loss= 352.956512, Training Accuracy= 0.89062
# Iter 72960, Minibatch Loss= 526.411499, Training Accuracy= 0.88281
# Iter 74240, Minibatch Loss= 285.401428, Training Accuracy= 0.89062
# Iter 75520, Minibatch Loss= 76.419395, Training Accuracy= 0.93750
# Iter 76800, Minibatch Loss= 595.176514, Training Accuracy= 0.87500
# Iter 78080, Minibatch Loss= 708.397156, Training Accuracy= 0.82031
# Iter 79360, Minibatch Loss= 274.537781, Training Accuracy= 0.89062
# Iter 80640, Minibatch Loss= 330.417297, Training Accuracy= 0.90625
# Iter 81920, Minibatch Loss= 194.165161, Training Accuracy= 0.89062
# Iter 83200, Minibatch Loss= 483.754028, Training Accuracy= 0.88281
# Iter 84480, Minibatch Loss= 366.934265, Training Accuracy= 0.89844
# Iter 85760, Minibatch Loss= 261.952454, Training Accuracy= 0.87500
# Iter 87040, Minibatch Loss= 761.298218, Training Accuracy= 0.82812
# Iter 88320, Minibatch Loss= 241.475769, Training Accuracy= 0.92188
# Iter 89600, Minibatch Loss= 394.439240, Training Accuracy= 0.83594
# Iter 90880, Minibatch Loss= 237.696640, Training Accuracy= 0.91406
# Iter 92160, Minibatch Loss= 341.288147, Training Accuracy= 0.89844
# Iter 93440, Minibatch Loss= 291.635895, Training Accuracy= 0.84375
# Iter 94720, Minibatch Loss= 108.130989, Training Accuracy= 0.91406
# Iter 96000, Minibatch Loss= 191.528793, Training Accuracy= 0.88281
# Iter 97280, Minibatch Loss= 190.625381, Training Accuracy= 0.92188
# Iter 98560, Minibatch Loss= 259.761230, Training Accuracy= 0.89062
# Iter 99840, Minibatch Loss= 378.687683, Training Accuracy= 0.86719
# Optimization Finished!
# Testing Accuracy: 0.902344
